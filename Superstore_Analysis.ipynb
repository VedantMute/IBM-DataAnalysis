# %% [markdown]
# # Vedant Mute
# vedantmute2004@gmail.com
# IBM Data Analysis
# # Superstore dataset Analysis

# %%
# Importing all necessary libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # <b>Reading dataset</b>

# %%
# Adding the datat set 
df=pd.read_csv("SampleSuperstore.csv")

# %%
df.shape
# Out:
# (9994, 13)

# %%
df.head(20)
# Out:
#          Ship Mode      Segment        Country             City  \
# 0     Second Class     Consumer  United States        Henderson
# 1     Second Class     Consumer  United States        Henderson
# 2     Second Class    Corporate  United States      Los Angeles
# 3   Standard Class     Consumer  United States  Fort Lauderdale
# 4   Standard Class     Consumer  United States  Fort Lauderdale
# 5   Standard Class     Consumer  United States      Los Angeles
# 6   Standard Class     Consumer  United States      Los Angeles
# 7   Standard Class     Consumer  United States      Los Angeles
# 8   Standard Class     Consumer  United States      Los Angeles
# 9   Standard Class     Consumer  United States      Los Angeles
# 10  Standard Class     Consumer  United States      Los Angeles
# 11  Standard Class     Consumer  United States      Los Angeles
# 12  Standard Class     Consumer  United States          Concord
# 13  Standard Class     Consumer  United States          Seattle
# ...

# %% [markdown]
#  Removing unnecessary column "Postal Code"

# %%
# Removing unnecessary column "Postal Code"
df.drop(columns="Postal Code", inplace=True)
df.head()
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#   Region         Category Sub-Category     Sales  Quantity  Discount    Profit
# 0  South        Furniture    Bookcases  261.9600         2      0.00   41.9136
# 1  South        Furniture       Chairs  731.9400         3      0.00  219.5820
# 2   West  Office Supplies       Labels   14.6200         2      0.00    6.8714
# 3  South        Furniture       Tables  957.5775         5      0.45 -383.0310
# 4  South  Office Supplies      Storage   22.3680         2      0.20    2.5164

# %% [markdown]
# # Unique Values

# %% [markdown]
# Category types in Data

# %%
print(df["Category"].unique())
# Out:
# ['Furniture' 'Office Supplies' 'Technology']

# %% [markdown]
# Category types in Sub-Category

# %%
print(df["Sub-Category"].unique())
# Out:
# ['Bookcases' 'Chairs' 'Labels' 'Tables' 'Storage' 'Furnishings' 'Art'
#  'Phones' 'Binders' 'Appliances' 'Paper' 'Accessories' 'Envelopes'
#  'Fasteners' 'Supplies' 'Machines' 'Copiers']

# %% [markdown]
# Segment types in Data

# %%
print(df["Segment"].unique())
# Out:
# ['Consumer' 'Corporate' 'Home Office']

# %% [markdown]
# Category types in Ship Mode

# %%
print(df["Ship Mode"].unique())
# Out:
# ['Second Class' 'Standard Class' 'First Class' 'Same Day']

# %% [markdown]
# # Number of items in each

# %% [markdown]
# Number of products in each category

# %%
print(df["Category"].value_counts())
# Out:
# Office Supplies    6026
# Furniture          2121
# Technology         1847
# Name: Category, dtype: int64

# %% [markdown]
# Number of products in each Segment

# %%
print(df["Segment"].value_counts())
# Out:
# Consumer       5191
# Corporate      3020
# Home Office    1783
# Name: Segment, dtype: int64

# %% [markdown]
# Number of Country

# %%
print(df["Country"].value_counts())
# Out:
# United States    9994
# Name: Country, dtype: int64

# %% [markdown]
# Number of products in each Sub-Category

# %%
print(df["Sub-Category"].value_counts())
# Out:
# Binders        1523
# Paper          1370
# Furnishings     957
# Phones          889
# Storage         846
# Art             796
# Accessories     775
# Chairs          617
# Appliances      466
# Labels          364
# Tables          319
# Envelopes       254
# Bookcases       228
# Fasteners       217
# Supplies        190
# Machines        115
# Copiers          68
# Name: Sub-Category, dtype: int64

# %% [markdown]
# Number of Regions

# %%
print(df["Region"].value_counts())
# Out:
# West       3203
# East       2848
# Central    2323
# South      1620
# Name: Region, dtype: int64

# %%
print(df["Profit"].value_counts())
# Out:
# 0.0000     65
# 6.2208     43
# 9.3312     38
# 5.4432     32
# 3.6288     32
#            ..
# 83.2508     1
# 16.1096     1
# 7.1988      1
# 1.6510      1
# 72.9480     1
# Name: Profit, Length: 7287, dtype: int64

# %% [markdown]
# # Statistical Data Summary

# %%
df.describe()
# Out:
#               Sales     Quantity     Discount       Profit
# count   9994.000000  9994.000000  9994.000000  9994.000000
# mean     229.858001     3.789574     0.156203    28.656896
# std      623.245101     2.225110     0.206452   234.260108
# min        0.444000     1.000000     0.000000 -6599.978000
# 25%       17.280000     2.000000     0.000000     1.728750
# 50%       54.490000     3.000000     0.200000     8.666500
# 75%      209.940000     5.000000     0.200000    29.364000
# max    22638.480000    14.000000     0.800000  8399.976000

# %% [markdown]
# # Information about the Data

# %%
# information about data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   object
#  1   Segment       9994 non-null   object
#  2   Country       9994 non-null   object
#  3   City          9994 non-null   object
#  4   State         9994 non-null   object
#  5   Region        9994 non-null   object
#  6   Category      9994 non-null   object
#  7   Sub-Category  9994 non-null   object
#  8   Sales         9994 non-null   float64
#  9   Quantity      9994 non-null   int64
#  10  Discount      9994 non-null   float64
#  11  Profit        9994 non-null   float64
# dtypes: float64(3), int64(1), object(8)
# memory usage: 937.1+ KB

# %% [markdown]
# # <b>Visualisation of Data</b>

# %% [markdown]
# State vs Profit Analysis

# %%
df.groupby("State")["Profit"].sum().plot.bar()
# Out:
# <Axes: xlabel='State'>

# %% [markdown]
# State vs Sales Analysis

# %%
df.groupby("State")["Sales"].sum().plot.line()
# Out:
# <Axes: xlabel='State'>

# %% [markdown]
# Region vs Profit Analysis

# %%
df.groupby("Region")["Profit"].sum().plot.bar()
# Out:
# <Axes: xlabel='Region'>

# %% [markdown]
# Region vs Sales Analysis

# %%
df.groupby("Region")["Sales"].sum().plot.bar()
# Out:
# <Axes: xlabel='Region'>

# %%
df.groupby("Region")["Profit"].sum().plot.pie(autopct="%1.0f%%")
#
# Out:
# <Axes: ylabel='Profit'>

# %% [markdown]
# Region vs Profit Analysis using pie chart

# %%
df.groupby("Region")["Sales"].sum().plot.pie(autopct="%1.0f%%")
# Out:
# <Axes: ylabel='Sales'>

# %% [markdown]
# Sub-Category Pie Plot

# %%
plt.figure(figsize=(8,6))
df["Sub-Category"].value_counts().plot.pie(autopct="%1.1f%%")
plt.show()

# %% [markdown]
# Sales vs Profit

# %%
df.groupby("Sub-Category")["Sales"].sum().plot.bar()
# Out:
# <Axes: xlabel='Sub-Category'>

# %%
df.groupby("Segment")["Sales"].sum().plot.bar()
# Segment vs Sales Analysis
# Out:
# <Axes: xlabel='Segment'>

# %%
df.groupby("Region")["Quantity"].sum().plot.pie(autopct="%1.0f%%")
# Out:
# <Axes: ylabel='Quantity'>

# %% [markdown]
# Most Profitable Sub Category

# %%
df["Sub-Category"].unique()
sub_categories_info=pd.DataFrame(df.groupby("Sub-Category")["Profit"].sum())
sub_categories_info.reset_index(inplace=True)
sub_categories_profit=sub_categories_info.sort_values(by="Profit",ascending=False)
sub_categories_profit.head(10)
# Out:
#    Sub-Category      Profit
# 6       Copiers  55617.8249
# 13       Phones  44515.7306
# 0   Accessories  41936.6357
# 12        Paper  34053.5693
# 3       Binders  30221.7633
# 5        Chairs  26590.1663
# 14      Storage  21278.8264
# 1    Appliances  18138.0054
# 9   Furnishings  13059.1436
# 7     Envelopes   6964.1767

# %%
plt.bar(sub_categories_profit["Sub-Category"],sub_categories_profit["Profit"])
plt.xticks(sub_categories_profit['Sub-Category'] , rotation = "vertical")
plt.xlabel("Sub Categories")
plt.ylabel("Profit")
plt.show()

# %% [markdown]
# Category having Most Sales

# %%
df["Category"].value_counts()
# Out:
# Office Supplies    6026
# Furniture          2121
# Technology         1847
# Name: Category, dtype: int64

# %% [markdown]
# Highest Sales Category

# %% [markdown]
# Which city has the highest Sales Volume

# %%
city_volume = pd.DataFrame(df.groupby('City')['Sales'].sum())
city_volume =city_volume.sort_values(by="Sales",ascending=False)
city_volume.head()
# Out:
#                     Sales
# City
# New York City  256368.161
# Los Angeles    175851.341
# Seattle        119540.742
# San Francisco  112669.092
# Philadelphia   109077.013

# %%
plt.bar(city_volume.index[0:20], city_volume['Sales'][0:20],color="blue")
plt.xticks(city_volume.index[0:20],rotation = 'vertical')
plt.xlabel("City" )
plt.ylabel("Sales")
plt.show()

# %% [markdown]
# What is the most profitable Region

# %%
pd.DataFrame(df.groupby("Region")["Profit"].sum())
# Out:
#               Profit
# Region
# Central   39706.3625
# East      91522.7800
# South     46749.4303
# West     108418.4489

# %% [markdown]
# Most profitable cutomer segment

# %%
df.groupby("Segment").sum()
# Out:
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_616\813857271.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby("Segment").sum()
#                     Sales  Quantity  Discount       Profit
# Segment
# Consumer     1.161401e+06     19521    820.91  134119.2092
# Corporate    7.061464e+05     11608    477.85   91979.1340
# Home Office  4.296531e+05      6744    262.33   60298.6785

# %%
df.groupby("Sales")["Profit"].sum().plot.box()
# Out:
# <Axes: >

# %%
df.groupby("Sub-Category")["Profit"].sum().plot.box()
# Out:
# <Axes: >
